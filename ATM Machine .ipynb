# %%
balance=10000
restart=('yes')
chances=3
pin=1234
while chances>0:
    Pin=int(input('pin of the account '))
    if Pin!=1234:
        print('you have entered wrong pin')
        chances=chances-1
    elif Pin:
        print('you entered your pin correctly')
        print('press 1 for your balance \npress 2 for withdrawal \npress 3 to pay in \npress 4 to return card')
        a=int(input('choice '))
        if a==1:
            print(balance)
            restart=input('would u like to go back')
            if restart==('no'):
                print('thankyou')
                
        elif a==2:
            withdrawal_amount=int(input('withdrawal_amount '))
            balance=balance-withdrawal_amount
            print(balance)
            restart=input('would u like to go back')
            if restart==('no'):
                print('thankyou')
                break
        elif a==3:
            payin=int(input('payin '))
            balance=balance+payin
            print(balance) 
            restart=input('would u like to go back')
            
            if restart==('no'):
                print('thankyou')
                break
        elif a==4:
            print('ur card is return ')
            print('thankyou for the service')
            break
    else:
        print('please enter correct number')
        restart=('yes')
        break
    if chances==0:
        print('no try')
        break
# Out:
# pin of the account 1234
# you entered your pin correctly
# press 1 for your balance
# press 2 for withdrawal
# press 3 to pay in
# press 4 to return card
# choice 1
# 10000
# would u like to go backyes
# pin of the account 1234
# you entered your pin correctly
# press 1 for your balance
# press 2 for withdrawal
# press 3 to pay in
# press 4 to return card
# choice 2
# withdrawal_amount 2000
# 8000
# would u like to go backyes
# pin of the account 3
# you have entered wrong pin
# pin of the account 1234
# you entered your pin correctly
# press 1 for your balance
# press 2 for withdrawal
# press 3 to pay in
# press 4 to return card
# choice 3
# payin 1000
# 9000
# would u like to go backyes
# pin of the account 1234
# you entered your pin correctly
# press 1 for your balance
# press 2 for withdrawal
# press 3 to pay in
# press 4 to return card
# choice 4
# ur card is return
# thankyou for the service
